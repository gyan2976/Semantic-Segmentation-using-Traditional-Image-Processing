# %% [markdown]
# **https://github.com/aptlin/simple-image-segmentation**

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Libraries**

# %%
import argparse
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import pairwise_distances_argmin
import numpy as np
import sys
sys.path.append('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data')
#import config
import os
import pandas as pd
from PIL import Image

# %%
pic = plt.imread('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg')/255  # dividing by 255 to bring the pixel values between 0 and 1
print(pic.shape)
plt.imshow(pic)
# Out:
# (400, 600, 3)

# %%
from sklearn.metrics import pairwise_distances_argmin
import numpy as np
#import config


class Segmentation:
    def __init__(self, n_clusters, random_seed=0, n_init=10):
        self.n_clusters = n_clusters
        self.random_seed = random_seed
        self.n_init = n_init

    def kmeans(self, points):
        """Adapted from https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html
        """
        rng = np.random.RandomState(self.random_seed)
        sample = rng.permutation(len(points))[: self.n_clusters]
        centers = points[sample]
        while True:
            labels = pairwise_distances_argmin(points, centers)
            new_centers = np.array(
                [points[labels == i].mean(0) for i in range(self.n_clusters)]
            )
            if np.all(centers == new_centers):
                break
            centers = new_centers

        return centers, labels

    def segment(self, img):
        height = img.shape[0]
        width = img.shape[1]
        channels = 1 if len(img.shape) < 3 else img.shape[2]
        flat_img = img.reshape((height * width, channels))
        for init in range(self.n_init):
            clusters, centers = self.kmeans(flat_img)
        return clusters, centers

# %%
import argparse
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

#from utils import Segmentation

if __name__ == "__main__":
    #parser = argparse.ArgumentParser()
    #parser.add_argument(
    #    "--image",
    #    help="The image to segment relative to the current folder.",
    #    default="/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg",
    #)
    #args = parser.parse_args()
    #img = plt.imread(args.image)
    img = plt.imread('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) / 255

    model = Segmentation(2)
    centers, labels = model.segment(gray)

    mask = (labels.reshape(*gray.shape) * 255).astype(np.uint8)

    # remove noise
    kernel = np.ones((4, 4), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=1)

    #cv2.imshow("Segmentation map", mask)
    cv2_imshow(mask)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7FBBEE82D150>

# %%
import argparse
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

#from utils import Segmentation

if __name__ == "__main__":
    #parser = argparse.ArgumentParser()
    #parser.add_argument(
    #    "--image",
    #    help="The image to segment relative to the current folder.",
    #    default="/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg",
    #)
    #args = parser.parse_args()
    #img = plt.imread(args.image)
    img = plt.imread('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/juice.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) / 255

    model = Segmentation(2)
    centers, labels = model.segment(gray)

    mask = (labels.reshape(*gray.shape) * 255).astype(np.uint8)

    # remove noise
    kernel = np.ones((4, 4), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=1)

    #cv2.imshow("Segmentation map", mask)
    cv2_imshow(mask)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1332x850 at 0x7FBBEE72D6D0>

# %%
import argparse
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

#from utils import Segmentation

if __name__ == "__main__":
    #parser = argparse.ArgumentParser()
    #parser.add_argument(
    #    "--image",
    #    help="The image to segment relative to the current folder.",
    #    default="/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg",
    #)
    #args = parser.parse_args()
    #img = plt.imread(args.image)
    img = plt.imread('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/friends.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) / 255

    model = Segmentation(2)
    centers, labels = model.segment(gray)

    mask = (labels.reshape(*gray.shape) * 255).astype(np.uint8)

    # remove noise
    kernel = np.ones((4, 4), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=1)

    #cv2.imshow("Segmentation map", mask)
    cv2_imshow(mask)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1000x667 at 0x7FBBEE7426D0>

# %%
import argparse
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

#from utils import Segmentation

if __name__ == "__main__":
    #parser = argparse.ArgumentParser()
    #parser.add_argument(
    #    "--image",
    #    help="The image to segment relative to the current folder.",
    #    default="/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg",
    #)
    #args = parser.parse_args()
    #img = plt.imread(args.image)
    img = plt.imread('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/kid.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) / 255

    model = Segmentation(2)
    centers, labels = model.segment(gray)

    mask = (labels.reshape(*gray.shape) * 255).astype(np.uint8)

    # remove noise
    kernel = np.ones((4, 4), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=1)

    #cv2.imshow("Segmentation map", mask)
    cv2_imshow(mask)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=720x479 at 0x7FBBEE868410>

# %%
import argparse
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

#from utils import Segmentation

if __name__ == "__main__":
    #parser = argparse.ArgumentParser()
    #parser.add_argument(
    #    "--image",
    #    help="The image to segment relative to the current folder.",
    #    default="/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg",
    #)
    #args = parser.parse_args()
    #img = plt.imread(args.image)
    img = plt.imread('/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/people.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) / 255

    model = Segmentation(2)
    centers, labels = model.segment(gray)

    mask = (labels.reshape(*gray.shape) * 255).astype(np.uint8)

    # remove noise
    kernel = np.ones((4, 4), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=1)

    #cv2.imshow("Segmentation map", mask)
    cv2_imshow(mask)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1000x575 at 0x7FBBEE72D6D0>

# %%
import argparse
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

#from utils import Segmentation

if __name__ == "__main__":
    #parser = argparse.ArgumentParser()
    #parser.add_argument(
    #    "--image",
    #    help="The image to segment relative to the current folder.",
    #    default="/content/drive/MyDrive/Computer Vision/Image Segmentation/Data/scenery.jpg",
    #)
    #args = parser.parse_args()
    #img = plt.imread(args.image)
    img = plt.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) / 255

    model = Segmentation(2)
    centers, labels = model.segment(gray)

    mask = (labels.reshape(*gray.shape) * 255).astype(np.uint8)

    # remove noise
    kernel = np.ones((4, 4), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=1)

    #cv2.imshow("Segmentation map", mask)
    cv2_imshow(mask)
    cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=585x966 at 0x7FBBEDEB7110>
